# %%
# task 
# how is work with deferente type of dataset,
# how is manupuiation data,

# link of dataset ('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# titanic.csv git

https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv

# %%
import pandas as pd

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
# last 5 
df.tail(4)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId            int64
# Survived               int64
# Pclass                 int64
# Name                  object
# Sex                   object
# Age                  float64
# SibSp                  int64
# Parch                  int64
# Ticket                object
# Fare                 float64
# Cabin                 object
# Embarked              object
# ineuron               object
# string_Cabin_list     object
# num_Cabin_list        object
# cabin_Number          object
# cabin_Letter          object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
col_name =df.dtypes[df.dtypes == 'object'].index

# %%
col_name
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[col_name]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[col_name].describe()
# Out:
#                                                  Name   Sex  Ticket Cabin  \
# count                                             891   891     891   204
# unique                                            891     2     681   147
# top     Appleton, Mrs. Edward Dale (Charlotte Lamson)  male  347082    G6
# freq                                                1   577       7     4
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# add a new column in dataset by use this command.


df['ineuron']='suth'

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# extract the name column
# it's a name colunm

df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# if you want to display 1 to 15 name, so use this code of line.
df['Name'][0:15]


# this is lidt clising opration.
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'].isnull() == True


# this code of Piece for check the null value of Age column.
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age'].isnull() == True].index

 # extract the index
    
# if i ask a question, how many places has null values.
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#             ...
#             832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#            dtype='int64', length=177)

# %%
li = [3,5,1,6,7,0]

# %%
li[5] # five is index number of list 
       # zero is a index value of list
# Out:
# 0

# %%
li[li == 4]  # four is a index value of list.
# Out:
# 3

# %%
len(df[df['Age'].isnull() == True].index)

# 177 places be had  a null values
# Out:
# 177

# %%
ind = df[df['Age'].isnull() == True].index

# %%
df.loc[ind]

# how do i row based selection of age index
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# extract the name of whose has maximum fare.

df['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
df[df['Fare'] == max(df['Fare'])]

# condition 
# it is all max fare
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#     ineuron
# 258    suth
# 679    suth
# 737    suth

# %%
# displat the name of max fare

df[df['Fare'] == max(df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
# 1. find out how many male and female passenger was onboarded.
# 2. how many survived we have.
# 3. how many casuality we have.
# 4. what is the name of a person who is the eldest one.
# 5. how many passenger do we have in first, second and third class.
# 6. how many parson we have whose name starts with "s"
# 7. try to create new colimn which is summation of "SibSp" and "parch"
# 8. how many person do we have below age of 25.
# 9. how many person died whose age was less then 40.
#10. from a cabin clumn seperate text and numeric value.

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 1. find out how many male and female passenger was onboarded.

df['Sex']

# extract column of sex.
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df[df['Sex'] == 'male']

# data is filter by male.
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked ineuron
# ...

# %%
# find the lenth of df of male.

len(df[df['Sex'] == 'male'])
# Out:
# 577

# %%
len(df[df['Sex'] == 'female'])
# Out:
# 314

# %%
df.groupby('Sex')

# %%
df.groupby('Sex').count()
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          314       314     314   314  261    314    314     314   314
# male            577       577     577   577  453    577    577     577   577
#
#         Cabin  Embarked  ineuron
# Sex
# female     97       312      314
# male      107       577      577

# %%
df.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
# 2. how many survived we have?



df['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df['Survived'] == 1
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Survived, Length: 891, dtype: bool

# %%
len(df[df['Survived'] == 1])


# how many survived we have.
# 342 survived peoples.
# Out:
# 342

# %%
df[df['Survived'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 3. how many casuality we have?

# %%
df['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df['Survived'] == 0
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Survived, Length: 891, dtype: bool

# %%
df[df['Survived'] == 0]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
len(df[df['Survived'] == 0])



# how many casuality we have.

# 549 people will be.
# Out:
# 549

# %% [markdown]
# # 4. what is the name of a person who is the eldest one?

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age']>60
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df['Age'] == df['Age'].max()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age'] == df['Age'].max()]

# this person is the eldest one
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked ineuron
# 630  male  80.0      0      0  27042  30.0   A23        S    suth

# %%
df[df['Age'] == df['Age'].max()]['Name']

# it is a person name
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %% [markdown]
# # 5. how many passenger do we
# #    have in first second and third class?

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked ineuron
# 0      0         A/5 21171   7.2500   NaN        S    suth
# 1      0          PC 17599  71.2833   C85        C    suth
# 2      0  STON/O2. 3101282   7.9250   NaN        S    suth

# %%
df['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df.groupby('Pclass')['Pclass'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %% [markdown]
# # 6. how many parson we have whose name starts with "s"

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'] == 'S'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Name, Length: 891, dtype: bool

# %%
df['Name'].str.startswith('s')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Name, Length: 891, dtype: bool

# %%
df[df['Name'].str.startswith("S")]
# Out:
#      PassengerId  Survived  Pclass  \
# 10            11         1       3
# 12            13         0       3
# 23            24         1       1
# 31            32         1       1
# 48            49         0       3
# ..           ...       ...     ...
# 851          852         0       3
# 862          863         1       1
# 863          864         0       3
# 880          881         1       2
# 884          885         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 48                                 Samaan, Mr. Youssef    male   NaN      2
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Name'].str.startswith("S")]['Name']
# Out:
# 10                       Sandstrom, Miss. Marguerite Rut
# 12                        Saundercock, Mr. William Henry
# 23                          Sloper, Mr. William Thompson
# 31        Spencer, Mrs. William Augustus (Marie Eugenie)
# 48                                   Samaan, Mr. Youssef
#                              ...
# 851                                  Svensson, Mr. Johan
# 862    Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# 863                    Sage, Miss. Dorothy Edith "Dolly"
# 880         Shelley, Mrs. William (Imanita Parrish Hall)
# 884                               Sutehall, Mr. Henry Jr
# Name: Name, Length: 86, dtype: object

# %%
len(df[df['Name'].str.startswith("S")]['Name'])
# Out:
# 86

# %% [markdown]
# # 7. try to create new column which is summation of "SibSp" and "parch" ?

# %%
df["Name"] = df["SibSp"] + df["Parch"]

# create a new column just like a dictionary.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Name     Sex   Age  SibSp  Parch  \
# 0            1         0       3     1    male  22.0      1      0
# 1            2         1       1     1  female  38.0      1      0
# 2            3         1       3     0  female  26.0      0      0
# 3            4         1       1     1  female  35.0      1      0
# 4            5         0       3     0    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked ineuron
# 0         A/5 21171   7.2500   NaN        S    suth
# 1          PC 17599  71.2833   C85        C    suth
# 2  STON/O2. 3101282   7.9250   NaN        S    suth
# 3            113803  53.1000  C123        S    suth
# 4            373450   8.0500   NaN        S    suth

# %% [markdown]
# # 8. how many person do we have
# # below age of 25 ?

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'] <25
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age'] <25]
# Out:
#      PassengerId  Survived  Pclass  Name     Sex   Age  SibSp  Parch  \
# 0              1         0       3     1    male  22.0      1      0
# 7              8         0       3     4    male   2.0      3      1
# 9             10         1       2     1  female  14.0      1      0
# 10            11         1       3     2  female   4.0      1      1
# 12            13         0       3     0    male  20.0      0      0
# ..           ...       ...     ...   ...     ...   ...    ...    ...
# 875          876         1       3     0  female  15.0      0      0
# 876          877         0       3     0    male  20.0      0      0
# 877          878         0       3     0    male  19.0      0      0
# 882          883         0       3     0  female  22.0      0      0
# 887          888         1       1     0  female  19.0      0      0
#
#         Ticket     Fare Cabin Embarked ineuron
# 0    A/5 21171   7.2500   NaN        S    suth
# ...

# %%
len(df[df['Age'] <25])
# Out:
# 278

# %% [markdown]
# # 9. how many person died whose age was less then 40.

# %%
df['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df['Survived'] == 0
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Survived, Length: 891, dtype: bool

# %%
(df['Survived'] == 0) & (df['Age'] <40)
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890     True
# Length: 891, dtype: bool

# %%
df[(df['Survived'] == 0) & (df['Age'] <40)]
# Out:
#      PassengerId  Survived  Pclass  Name     Sex   Age  SibSp  Parch  \
# 0              1         0       3     1    male  22.0      1      0
# 4              5         0       3     0    male  35.0      0      0
# 7              8         0       3     4    male   2.0      3      1
# 12            13         0       3     0    male  20.0      0      0
# 13            14         0       3     6    male  39.0      1      5
# ..           ...       ...     ...   ...     ...   ...    ...    ...
# 883          884         0       2     0    male  28.0      0      0
# 884          885         0       3     0    male  25.0      0      0
# 885          886         0       3     5  female  39.0      0      5
# 886          887         0       2     0    male  27.0      0      0
# 890          891         0       3     0    male  32.0      0      0
#
#                Ticket    Fare Cabin Embarked ineuron
# 0           A/5 21171   7.250   NaN        S    suth
# ...

# %%
len((df['Survived'] == 0) & (df['Age'] <40))
# Out:
# 891

# %% [markdown]
# # 10. from a cabin clumn seperate text and numeric value.

# %%
df['Cabin'].value_counts()
# Out:
# G6             4
# C23 C25 C27    4
# B96 B98        4
# F2             3
# C22 C26        3
#               ..
# E17            1
# E58            1
# B82 B84        1
# F E69          1
# D9             1
# Name: Cabin, Length: 147, dtype: int64

# %%
df['Cabin'] == type('G6')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Cabin, Length: 891, dtype: bool

# %%
len(df['Cabin'] == type('E17'))
# Out:
# 891

# %%
import re

# solve this proble with regular expresion  module.

# %%
df2 = pd.DataFrame(df.Cabin.str.split("([a-zA-Z]+)([^a-zA-Z]+)"))
df2
# Out:
#             Cabin
# 0             NaN
# 1     [, C, 85, ]
# 2             NaN
# 3    [, C, 123, ]
# 4             NaN
# ..            ...
# 886           NaN
# 887   [, B, 42, ]
# 888           NaN
# 889  [, C, 148, ]
# 890           NaN
#
# [891 rows x 1 columns]

# %%
replace = re.compile("([a-zA-Z]+)")

df['string_Cabin_list'] = df['Cabin'].str.extract(replace)
df['num_Cabin_list'] = df['Cabin'].str.extract(replace, "")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Name     Sex   Age  SibSp  Parch  \
# 0            1         0       3     1    male  22.0      1      0
# 1            2         1       1     1  female  38.0      1      0
# 2            3         1       3     0  female  26.0      0      0
# 3            4         1       1     1  female  35.0      1      0
# 4            5         0       3     0    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked ineuron number_Cabin_list  \
# 0         A/5 21171   7.2500   NaN        S    suth               NaN
# 1          PC 17599  71.2833   C85        C    suth                 C
# 2  STON/O2. 3101282   7.9250   NaN        S    suth               NaN
# 3            113803  53.1000  C123        S    suth                 C
# 4            373450   8.0500   NaN        S    suth               NaN
#
#   string_Cabin_list num_Cabin_list Cabin_number Cabin_letter Cabin_Number  \
# ...

# %%
df['cabin_Number'] = df['Cabin'].str.replace('([A-Za-z]+)',"")
df['cabin_Letter'] = df['Cabin'].str.extract('([A-Za-z]+)')
# Out:
# <ipython-input-18-a7fa2ae2ab8e>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['cabin_Number'] = df['Cabin'].str.replace('([A-Za-z]+)',"")
