# %%
# task 

# link of class lecture = https://learn.ineuron.ai/lesson/March-6th-Live-Class/6224ca23760e3e2dbff83873/course/Full-Stack-Data-Science-Upcoming-batch/61b30b40b733d139bc0e7ffb/batch/61b30b40b733d139bc0e6ffe
    
# 35:00

# 1:50

# link of data = https://github.com/iNeuronai/same-resume-year-wise

# %%
read all the resume from ineuron git in pdf, word, and try to create a 
dataframe with resume name as a index value, and in column i am 
expecting id, linked in id, git id, sills as a result.
# Out:
#   File "<ipython-input-2-6e30e820e378>", line 1
#     read all the resume from ineuron git in pdf, word, and try to create a
#          ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# handel Nun values.

df.dropna()

# this command is not drop parmanent nun value.
# is not uppdate original record
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(axis=1)

# drop columnes.
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257   35.674426    0.464481
# std     247.052476    0.470725    0.515187   15.643866    0.644159
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     263.500000    0.000000    1.000000   24.000000    0.000000
# 50%     457.000000    1.000000    1.000000   36.000000    0.000000
# 75%     676.000000    1.000000    1.000000   47.500000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.dropna(axis = 1,how ='all')
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.fillna(value='sudh')
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.fillna(value=df['Age'].mean())
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby('Survived').describe()
# Out:
#          PassengerId                                                           \
#                count        mean         std  min    25%    50%    75%    max
# Survived
# 0               60.0  402.983333  252.917183  7.0  174.0  359.0  634.5  873.0
# 1              123.0  480.918699  241.058955  2.0  309.0  497.0  690.5  890.0
#
#          Pclass            ... Parch        Fare                              \
#           count      mean  ...   75%  max  count       mean        std   min
# Survived                   ...
# 0          60.0  1.216667  ...   1.0  4.0   60.0  64.048262  61.693457  0.00
# 1         123.0  1.178862  ...   1.0  2.0  123.0  85.821107  81.843522  8.05
#
#
#             25%      50%   75%       max
# Survived
# 0         27.45  45.3104  79.2  263.0000
# 1         30.50  69.3000  93.5  512.3292
#
# [2 rows x 48 columns]

# %%
df.groupby('Survived').describe()['PassengerId']
# Out:
#           count        mean         std  min    25%    50%    75%    max
# Survived
# 0          60.0  402.983333  252.917183  7.0  174.0  359.0  634.5  873.0
# 1         123.0  480.918699  241.058955  2.0  309.0  497.0  690.5  890.0

# %%
# transpose table.

df.groupby('Survived').describe()['PassengerId'].T

# i can also write code like this

# df.groupby('Survived').describe()['PassengerId'].transpose

# %%
# concatinate;

pd.read_csv("C:\\Users\\ambreesh kumar\\Downloads\\bank\\bank.csv", sep=";")
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
df = pd.read_csv("C:\\Users\\ambreesh kumar\\Downloads\\bank\\bank.csv", sep=";")

# %%
l = []
for i in df['education'].unique():
    l.append(df[df['education'] == i])

# %%
df2 = l[0]

# %%
df3 = l[1]

# %%
df2
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
df3
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
# join operation.

pd.concat([df2,df3])
# Out:
#       age          job   marital  education default  balance housing loan  \
# 0      30   unemployed   married    primary      no     1787      no   no
# 9      43     services   married    primary      no      -88     yes  yes
# 18     25  blue-collar    single    primary      no     -221     yes   no
# 26     55  blue-collar   married    primary      no      627     yes   no
# 36     78      retired  divorced    primary      no      229      no   no
# ...   ...          ...       ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar   married  secondary      no     1205     yes   no
# 4515   32     services    single  secondary      no      473     yes   no
# 4516   33     services   married  secondary      no     -333     yes   no
# 4518   57   technician   married  secondary      no      295      no   no
# 4519   28  blue-collar   married  secondary      no     1137      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
pd.concat([df2,df3],axis = 1)
# Out:
#        age         job  marital education default  balance housing loan  \
# 0     30.0  unemployed  married   primary      no   1787.0      no   no
# 1      NaN         NaN      NaN       NaN     NaN      NaN     NaN  NaN
# 4      NaN         NaN      NaN       NaN     NaN      NaN     NaN  NaN
# 7      NaN         NaN      NaN       NaN     NaN      NaN     NaN  NaN
# 9     43.0    services  married   primary      no    -88.0     yes  yes
# ...    ...         ...      ...       ...     ...      ...     ...  ...
# 4514   NaN         NaN      NaN       NaN     NaN      NaN     NaN  NaN
# 4515   NaN         NaN      NaN       NaN     NaN      NaN     NaN  NaN
# 4516   NaN         NaN      NaN       NaN     NaN      NaN     NaN  NaN
# 4518   NaN         NaN      NaN       NaN     NaN      NaN     NaN  NaN
# 4519   NaN         NaN      NaN       NaN     NaN      NaN     NaN  NaN
#
#        contact   day  ... loan   contact   day  month  duration campaign  \
# ...

# %%
# subset of concatinate.

# i am expecting a row type data.

df2.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df2 = df2.head()[['age','job','marital']]

# %%
df2

# %%
df5 = pd.concat([df2,df3],axis = 1)
df5

# %%
df5['age']

# %%
# iloc take two the values first is rwo and second is colunm.
# 3 is here third column

df5.iloc[:,3]

# %%
# faching a records from df5 age column.
# use iloc function.

df5.iloc[:, 3],[3,4]

# %%
df5.iloc[9,],[3,4]

# %%
# how to handle data with iloc() function.
# how is the merge() function used?
 
# Which function to use for data handling
# Which function is used to handle the dataset

# %%
pd.merge(df2,df3,on = 'age')
# Out:
#        age       job_x marital_x education_x default_x  balance_x housing_x  \
# 0       30  unemployed   married     primary        no       1787        no
# 1       30  unemployed   married     primary        no       1787        no
# 2       30  unemployed   married     primary        no       1787        no
# 3       30  unemployed   married     primary        no       1787        no
# 4       30  unemployed   married     primary        no       1787        no
# ...    ...         ...       ...         ...       ...        ...       ...
# 37881   66     retired   married     primary        no        747        no
# 37882   66     retired   married     primary        no        206        no
# 37883   66     retired   married     primary        no        206        no
# 37884   79     retired   married     primary        no       8556        no
# 37885   79     retired   married     primary        no        429        no
#
# ...

# %%
pd.merge(df2,df3,on = 'age',how = 'left')
# Out:
#        age          job_x marital_x education_x default_x  balance_x  \
# 0       30     unemployed   married     primary        no       1787
# 1       30     unemployed   married     primary        no       1787
# 2       30     unemployed   married     primary        no       1787
# 3       30     unemployed   married     primary        no       1787
# 4       30     unemployed   married     primary        no       1787
# ...    ...            ...       ...         ...       ...        ...
# 37888   60  self-employed   married     primary        no        362
# 37889   60  self-employed   married     primary        no        362
# 37890   60  self-employed   married     primary        no        362
# 37891   60  self-employed   married     primary        no        362
# 37892   60  self-employed   married     primary        no        362
#
#       housing_x loan_x contact_x  day_x  ... loan_y  contact_y  day_y  \
# ...

# %%
# join() function.

# reset_index()

# %%
pd.merge(df3.reset_index(),df2.reset_index())
# Out:
# Empty DataFrame
# Columns: [index, age, job, marital, education, default, balance, housing, loan, contact, day, month, duration, campaign, pdays, previous, poutcome, y]
# Index: []

# %% [markdown]
# #

# %%
# link of lecture video: 'https://learn.ineuron.ai/lesson/12th-March-Pandas-and-Numpy/622ced70528fc5011f55ff90/course/Full-Stack-Data-Science-Upcoming-batch/61b30b40b733d139bc0e7ffb/batch/61b30b40b733d139bc0e6ffe'

# time 20:00

# %%
import pandas as pd

# %%
pd.DataFrame({'col1' : [1,2,3,4,5],
            'col2' : [45,56,67,34,34],
            'col3' : "shudhanshu kumar krish ineuron one"
})
# Out:
#    col1  col2                                col3
# 0     1    45  shudhanshu kumar krish ineuron one
# 1     2    56  shudhanshu kumar krish ineuron one
# 2     3    67  shudhanshu kumar krish ineuron one
# 3     4    34  shudhanshu kumar krish ineuron one
# 4     5    34  shudhanshu kumar krish ineuron one

# %%
# if i want splite the col3 so what i do.

df = pd.DataFrame({'col1' : [1,2,3,4,5],
            'col2' : [45,56,67,34,34],
            'col3' : "shudhanshu kumar krish ineuron one".split()
})


# like that

# %%
df
# Out:
#    col1  col2        col3
# 0     1    45  shudhanshu
# 1     2    56       kumar
# 2     3    67       krish
# 3     4    34     ineuron
# 4     5    34         one

# %%
# create a new column for store the square of the first column.


df['col4'] = df['col1']**2

# %%
df
# Out:
#    col1  col2        col3  col4
# 0     1    45  shudhanshu     1
# 1     2    56       kumar     4
# 2     3    67       krish     9
# 3     4    34     ineuron    16
# 4     5    34         one    25

# %%
# create the fivth column with first letet of third col.

# %%
df['col5'] = df['col3'].str[0]

# %%
df
# Out:
#    col1  col2        col3  col4 col5
# 0     1    45  shudhanshu     1    s
# 1     2    56       kumar     4    k
# 2     3    67       krish     9    k
# 3     4    34     ineuron    16    i
# 4     5    34         one    25    o

# %%
def test(a):
    return a**2

# %%
# use test() function with apply key word

# Pandas.apply allow the users to pass a function and apply it on 
# every single value of the Pandas series. It comes as a huge 
# improvement for the pandas library as this function helps to 
# segregate data according to the conditions required due to which 
# it is efficiently used in data science and machine learning.



df['col4_4'] = df['col1'].apply(test)

# %%
df
# Out:
#    col1  col2        col3  col4 col5  col4_4 col6 col6_6  col7      col8
# 0     1    45  shudhanshu     1    s       1    s      s    10  3.806662
# 1     2    56       kumar     4    k       4    z      z     5  4.025352
# 2     3    67       krish     9    k       9    z      z     5  4.204693
# 3     4    34     ineuron    16    i      16    z      z     7  3.526361
# 4     5    34         one    25    o      25    z      z     3  3.526361

# %%
# create the col6 with condition.
# if in col numbre 5 value is S in that case keep it and in ather case 
# generate Z value.

def test1(a):
    if (a[0]== 's'):
         return 's'
    else:
        return 'z'

# %%
def test1(a):
    if (a[0]== 's'):
         return 's'
    else:
        return 'z'

# %%
df['col6'] = df['col5'].apply(test1)

# %%
df
# Out:
#    col1  col2        col3  col4 col5  col4_4 col6 col6_6  col7      col8
# 0     1    45  shudhanshu     1    s       1    s      s    10  3.806662
# 1     2    56       kumar     4    k       4    z      z     5  4.025352
# 2     3    67       krish     9    k       9    z      z     5  4.204693
# 3     4    34     ineuron    16    i      16    z      z     7  3.526361
# 4     5    34         one    25    o      25    z      z     3  3.526361

# %%
# i can also use lamda function on over here

df['col6_6'] = df['col5'].apply(lambda a: 's' if a == 's' else 'z')

# %%
df
# Out:
#    col1  col2        col3  col4 col5  col4_4 col6 col6_6
# 0     1    45  shudhanshu     1    s       1    s      s
# 1     2    56       kumar     4    k       4    z      z
# 2     3    67       krish     9    k       9    z      z
# 3     4    34     ineuron    16    i      16    z      z
# 4     5    34         one    25    o      25    z      z

# %%
df['col7'] = df['col3'].apply(len)

# %%
df
# Out:
#    col1  col2        col3  col4 col5  col4_4 col6 col6_6  col7
# 0     1    45  shudhanshu     1    s       1    s      s    10
# 1     2    56       kumar     4    k       4    z      z     5
# 2     3    67       krish     9    k       9    z      z     5
# 3     4    34     ineuron    16    i      16    z      z     7
# 4     5    34         one    25    o      25    z      z     3

# %%
import math

# %%
df['col8'] = df['col2'].apply(math.log)

# %%
df
# Out:
#    col1  col2        col3  col4 col5  col4_4 col6 col6_6  col7      col8
# 0     1    45  shudhanshu     1    s       1    s      s    10  3.806662
# 1     2    56       kumar     4    k       4    z      z     5  4.025352
# 2     3    67       krish     9    k       9    z      z     5  4.204693
# 3     4    34     ineuron    16    i      16    z      z     7  3.526361
# 4     5    34         one    25    o      25    z      z     3  3.526361
